# %% [markdown]
# # RETAIL DATA ANALYSIS

# %% [markdown]
# ### Import all libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the Dataset

# %%
Retail=pd.read_csv(r'C:\Users\Lenovo\Downloads\new_retail_data.csv\new_retail_data.csv')

# %%
Retail.head()
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  ...  Total_Amount Product_Category  Product_Brand  \
# ...

# %%
Retail.dropna()
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %%
Retail.isnull().sum()
# Out:
# Transaction_ID      333
# Customer_ID         308
# Name                382
# Email               347
# Phone               362
# Address             315
# City                248
# State               281
# Zipcode             340
# Country             271
# Age                 173
# Gender              317
# Income              290
# Customer_Segment    215
# Date                359
# Year                350
# Month               273
# Time                350
# Total_Purchases     361
# Amount              357
# Total_Amount        350
# Product_Category    283
# Product_Brand       281
# Product_Type          0
# Feedback            184
# Shipping_Method     337
# Payment_Method      297
# Order_Status        235
# Ratings             184
# products              0
# dtype: int64

# %%
Retail.fillna(0)
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %%
Retail=Retail.drop_duplicates()

# %%
Retail['Income'].fillna(value=0,inplace=True)
Retail['Total_Purchases'].fillna(value=0,inplace=True)
Retail['Amount'].fillna(value=0,inplace=True)
Retail['Total_Amount'].fillna(value=0,inplace=True)
Retail['Ratings'].fillna(value=0,inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3600\3435805984.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Retail['Total_Purchases'].fillna(value=0,inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3600\3435805984.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
Retail.isnull().sum()
# Out:
# Transaction_ID      333
# Customer_ID         308
# Name                382
# Email               347
# Phone               362
# Address             315
# City                248
# State               281
# Zipcode             340
# Country             271
# Age                 173
# Gender              317
# Income                0
# Customer_Segment    215
# Date                359
# Year                350
# Month               273
# Time                350
# Total_Purchases       0
# Amount                0
# Total_Amount          0
# Product_Category    283
# Product_Brand       281
# Product_Type          0
# Feedback            184
# Shipping_Method     337
# Payment_Method      297
# Order_Status        235
# Ratings               0
# products              0
# dtype: int64

# %% [markdown]
# # Convert Data Types

# %%
from datetime import datetime

# %%
Retail['Date']=pd.to_datetime(Retail['Date'].str.strip(), format='mixed',dayfirst=True)

# %%
Retail['Date']
# Out:
# 0        2023-09-18
# 1        2023-12-31
# 2        2023-04-26
# 3        2023-08-05
# 4        2024-10-01
#             ...
# 302005   2024-01-20
# 302006   2023-12-28
# 302007   2024-02-27
# 302008   2023-03-09
# 302009   2024-08-01
# Name: Date, Length: 302006, dtype: datetime64[ns]

# %%
Retail.shape
# Out:
# (302006, 30)

# %%
Retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302006 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301673 non-null  float64
#  1   Customer_ID       301698 non-null  float64
#  2   Name              301624 non-null  object
#  3   Email             301659 non-null  object
#  4   Phone             301644 non-null  float64
#  5   Address           301691 non-null  object
#  6   City              301758 non-null  object
#  7   State             301725 non-null  object
#  8   Zipcode           301666 non-null  float64
#  9   Country           301735 non-null  object
#  10  Age               301833 non-null  float64
#  11  Gender            301689 non-null  object
#  12  Income            302006 non-null  object
#  13  Customer_Segment  301791 non-null  object
#  14  Date              301647 non-null  object
#  15  Year              301656 non-null  float64
# ...

# %%
Retail.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Name', 'Email', 'Phone', 'Address',
#        'City', 'State', 'Zipcode', 'Country', 'Age', 'Gender', 'Income',
#        'Customer_Segment', 'Date', 'Year', 'Month', 'Time', 'Total_Purchases',
#        'Amount', 'Total_Amount', 'Product_Category', 'Product_Brand',
#        'Product_Type', 'Feedback', 'Shipping_Method', 'Payment_Method',
#        'Order_Status', 'Ratings', 'products'],
#       dtype='object')

# %%
Retail.nunique()
# Out:
# Transaction_ID      294461
# Customer_ID          86766
# Name                159390
# Email                52897
# Phone               299295
# Address             299329
# City                   130
# State                   54
# Zipcode              93978
# Country                  5
# Age                     53
# Gender                   2
# Income                   4
# Customer_Segment         3
# Date                   366
# Year                     2
# Month                   12
# Time                 83677
# Total_Purchases         11
# Amount              299298
# Total_Amount        299306
# Product_Category         5
# Product_Brand           18
# Product_Type            33
# Feedback                 4
# Shipping_Method          3
# Payment_Method           4
# Order_Status             4
# Ratings                  5
# products               318
# dtype: int64

# %% [markdown]
# ### Checking Duplicates

# %%
Retail[Retail.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Customer_ID, Name, Email, Phone, Address, City, State, Zipcode, Country, Age, Gender, Income, Customer_Segment, Date, Year, Month, Time, Total_Purchases, Amount, Total_Amount, Product_Category, Product_Brand, Product_Type, Feedback, Shipping_Method, Payment_Method, Order_Status, Ratings, products]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# # Detect Outlier

# %%
from scipy.stats import zscore
Retail['z_score']=zscore(Retail['Amount'])
outliers=Retail[Retail['z_score'].abs()>3]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Customer_ID, Name, Email, Phone, Address, City, State, Zipcode, Country, Age, Gender, Income, Customer_Segment, Date, Year, Month, Time, Total_Purchases, Amount, Total_Amount, Product_Category, Product_Brand, Product_Type, Feedback, Shipping_Method, Payment_Method, Order_Status, Ratings, products, z_score]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
Retail.describe()
# Out:
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016730e+05  301698.000000  3.016440e+05  301666.000000
# mean     5.495836e+06   55006.868783  5.501470e+09   50299.030368
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32470.000000  3.255061e+09   25425.000000
# 50%      5.499735e+06   55013.000000  5.505812e+09   50602.500000
# 75%      7.739524e+06   77511.000000  7.749883e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
# std      2.595578e+06   26005.672186  2.596024e+09   28972.877050
#
#                  Age                           Date           Year  \
# count  301833.000000                         301647  301656.000000
# mean       35.481034  2023-08-30 16:16:16.431391232    2023.165115
# min        18.000000            2023-03-01 00:00:00    2023.000000
# 25%        22.000000            2023-05-31 00:00:00    2023.000000
# ...

# %%
import seaborn as sns

# %% [markdown]
# ### Visualize the data

# %%
plt.figure(figsize=(10,6))
sns.countplot(Retail['Product_Category'],color='red')
plt.title('Product category Distribution')
plt.xlabel('Frequency')
plt.ylabel('Product Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Sales Distribution

# %%
plt.figure(figsize=(10,6))
sns.histplot(Retail['Total_Purchases'],kde=True,bins=30)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Outlier of Sales Distribution

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=Retail['Total_Purchases'])
plt.title('Sales Distribution with Outliers')
plt.show()

# %% [markdown]
# ### Total Sales Over Time

# %%
plt.figure(figsize=(12,6))
Retail.groupby('Date')['Total_Purchases'].sum().plot()
plt.title('Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Top Selling Products

# %%
top_products=Retail.groupby('products')['Total_Purchases'].sum().reset_index()
top_products_sorted=top_products.sort_values(by='Total_Purchases',ascending=False)

# %%
top_products_sorted.head(10)
#type(top_products_sorted.head(10))
# Out:
#             products  Total_Purchases
# 98   Distilled water          13465.0
# 39     Bottled water          13399.0
# 270     Spring water          13320.0
# 15    Artesian water          13201.0
# 190          Mystery          13160.0
# 118   Flavored water          13110.0
# 181    Mineral water          13046.0
# 67     Coconut water          13016.0
# 8     Alkaline water          12945.0
# 5          Adventure          12922.0

# %% [markdown]
# ### Visualization of Top Selling Products

# %%
plt.figure(figsize=(12,6))
sns.barplot(y='Total_Purchases',x='products',data=top_products_sorted.head(10),color='purple')
plt.title('Top 10 Selling Products')
plt.xlabel('Products')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %% [markdown]
# # daily sales

# %%
daily_sales=Retail.groupby('Date')['Total_Purchases'].sum().reset_index()
daily_sales.head()
# Out:
#         Date  Total_Purchases
# 0 2023-01-03           4234.0
# 1 2023-01-04           4341.0
# 2 2023-01-05           4317.0
# 3 2023-01-06           4723.0
# 4 2023-01-07           4705.0

# %%
plt.figure(figsize=(12,6))
plt.plot(daily_sales['Date'],daily_sales['Total_Purchases'],marker='o',color='black')
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Monthly Sales

# %%
Retail['Year']=Retail['Date'].dt.year
Retail['Month']=Retail['Date'].dt.month
monthly_sales=Retail.groupby(['Year','Month'])['Total_Purchases'].sum().reset_index()
monthly_sales['Year_Month']=monthly_sales['Year'].astype(str)+'-'+monthly_sales['Month'].astype(str).str.zfill(2)
monthly_sales.head()
# Out:
#      Year  Month  Total_Purchases  Year_Month
# 0  2023.0    1.0          44511.0  2023.0-1.0
# 1  2023.0    2.0          44115.0  2023.0-2.0
# 2  2023.0    3.0         128281.0  2023.0-3.0
# 3  2023.0    4.0         124419.0  2023.0-4.0
# 4  2023.0    5.0         126409.0  2023.0-5.0

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Year_Month',y='Total_Purchases',data=monthly_sales,marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Seasonal Sales

# %%
seasonal_map={
    1:'Winter',2:'Winter',3:'Spring',4:'Spring',5:'Spring',6:'Summer',
    7:'Summer',8:'Summer',9:'Fall',10:'Fall',11:'Fall',12:'Winter'
}
Retail['Season']=Retail['Month'].replace(seasonal_map)
Retail['Quarter']=Retail['Date'].dt.to_period('Q')
seasonal_sales=Retail.groupby('Season')['Total_Purchases'].sum().reset_index()
quarterly_sales=Retail.groupby('Quarter')['Total_Purchases'].sum().reset_index()

# %%
seasonal_sales
# Out:
#        Season  Total_Purchases
# 0       April         221817.0
# 1      August         177049.0
# 2    December         101204.0
# 3    February          98147.0
# 4     January         198778.0
# 5        July         166106.0
# 6        June          98067.0
# 7       March         102814.0
# 8         May         151422.0
# 9    November          97878.0
# 10    October         102276.0
# 11  September          99671.0

# %%
quarterly_sales
# Out:
#   Quarter  Total_Purchases
# 0  2023Q1         216907.0
# 1  2023Q2         374217.0
# 2  2023Q3         378805.0
# 3  2023Q4         379066.0
# 4  2024Q1         186305.0
# 5  2024Q2          26828.0
# 6  2024Q3          25926.0
# 7  2024Q4          26832.0

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Season',y='Total_Purchases',data=seasonal_sales)
plt.title('Sales by season')
plt.xlabel('Season')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Quarter',y='Total_Purchases',data=quarterly_sales)
plt.title('Sales by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # Demographic Analysis

# %%
Retail['Age'].hist(bins=20,color='pink')
plt.title('Age Distribution of Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Gender Distribution of Customer

# %%
Retail['Gender'].value_counts().plot(kind='bar',color='brown')
plt.title('Gender Distribution of Customer')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Top 10 City by Customers

# %%
Retail['City'].value_counts().head(10).plot(kind='bar',color='lightcoral')
plt.title('Top 10 City by Customer Count')
plt.xlabel('City')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Buying Patterns Analysis

# %%
Retail['Date']=pd.to_datetime(Retail['Date'])
Retail['purchase_weekday']=Retail['Date'].dt.weekday
Retail['purchase_weekday'].value_counts().sort_index().plot(kind='bar') 
plt.title('Purchases by Weekday')
plt.xlabel('Weekday')
plt.ylabel('Number of Purchases')
plt.show()

# %% [markdown]
# ### Basket Size Distribution

# %%
Retail['basket_size']=Retail.groupby('Transaction_ID')['products'].transform('count')
Retail['basket_size'].hist(bins=20,color='lightgreen',edgecolor='black')
plt.title('Basket Size Distribution(items per transaction)')
plt.xlabel('Number of Items per Transaction')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Purchase Frequency Distribution

# %%
purchase_count_per_customer=Retail['Customer_ID'].value_counts()
purchase_count_per_customer.plot(kind='hist',bins=20,color='lightblue',edgecolor='black')
plt.title('Distribution of Purchase Frequency')
plt.xlabel('Number of Purchases')
plt.ylabel('Number of Customer')
plt.show()

# %% [markdown]
# # Product Return Rates

# %%
Retail['return_flag']=Retail['Transaction_ID'].isin(Retail['Transaction_ID']).astype(int)

# %% [markdown]
# ### Overall Return Rate

# %%
total_sales=len(Retail)
total_returns=Retail['return_flag'].sum()
return_rate=total_returns/total_sales
print(f"Overall Return Rate:{return_rate:.2%}")
# Out:
# Overall Return Rate:100.00%

# %%
product_return_rate=Retail.groupby('products').agg(
    total_sales=('products','size'),
    total_returns=('return_flag','sum')
)
product_return_rate['return_rate']=product_return_rate['total_returns']/product_return_rate['total_sales']
product_return_rate=product_return_rate.reset_index()

# %% [markdown]
# ### Visualization of Product Return Rate

# %%
sns.histplot(product_return_rate['return_rate'],bins=30,kde=True)
plt.title('Distribution of Product Return Rate')
plt.xlabel('Return Rate')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Product categories

# %%
category_return_rate=Retail.groupby('Product_Category').agg(
    total_sales=('products','size'),
    total_returns=('return_flag','sum')
)
category_return_rate['return_rate']=category_return_rate['total_returns']/category_return_rate['total_sales']

# %% [markdown]
# # Customer Demographics

# %%
customer_return_rate=Retail.groupby('Customer_ID').agg(
    total_sales=('Transaction_ID','size'),
    total_returns=('return_flag','sum')
)
customer_return_rate['return_rate']=customer_return_rate['total_returns']/customer_return_rate['total_sales']

# %% [markdown]
# # Time Based Analysis

# %%
Retail['return_month']=Retail['Date'].dt.month
monthly_return_rate=Retail.groupby('return_month').agg(
    total_sales=('Transaction_ID','size'),
    total_returns=('return_flag','sum')
)
monthly_return_rate['return_rate']=monthly_return_rate['total_returns']/monthly_return_rate['total_sales']

# %% [markdown]
# # RFM Customer Segmentation

# %%
from datetime import datetime

# %%
Retail['PurchaseDate']=pd.to_datetime(Retail['Date'])
current_date=datetime.now()

# %% [markdown]
# ### RFM Metrics

# %%
rfm=Retail.groupby('Customer_ID').agg(
    Recency=('Date',lambda x:(current_date-x.max()).days),
    Frequency=('Date','count'),
    Monetary=('Amount','sum')
).reset_index()
print("RFM Metrics:\n",rfm)
# Out:
# RFM Metrics:
#         Customer_ID  Recency  Frequency     Monetary
# 0          10000.0    465.0          4   940.297743
# 1          10001.0    467.0          5  1517.921543
# 2          10002.0    457.0          5  1117.164676
# 3          10003.0    590.0          2   266.301835
# 4          10004.0    393.0          2   460.702696
# ...            ...      ...        ...          ...
# 86761      99995.0    443.0          8  1507.445075
# 86762      99996.0    426.0          4  1015.695955
# 86763      99997.0    178.0          4  1020.099125
# 86764      99998.0    361.0          5  1299.841122
# 86765      99999.0    515.0          2   860.041714
#
# [86766 rows x 4 columns]

# %% [markdown]
# ### RFM Score

# %%
rfm['Recencyscore']=pd.qcut(rfm['Recency'],5,labels=[5,4,3,2,1])
rfm['FrequencyScore']=pd.qcut(rfm['Frequency'],5,labels=[1,2,3,4,5])
rfm['Monetaryscore']=pd.qcut(rfm['Monetary'],5,labels=[1,2,3,4,5])
rfm['RFMScore']=rfm['Recencyscore'].astype(str)+rfm['FrequencyScore'].astype(str)+rfm['Monetaryscore'].astype(str)

# %% [markdown]
# ### Customer Segment

# %%
def segment_customer(row):
    if row['RFMScore']=='555':
        return 'Best Customers'
    elif row['RFMScore']=='111':
        return 'Lost Customers'
    elif row['RFMScore'].startswith('5'):
        return 'Loyal Customers'
    elif row['RFMScore'].endswith('1'):
        return 'At Risk'
    else:
        return 'Others'

# %%
rfm['Segment']=rfm.apply(segment_customer,axis=1)
print("\nCustomer Segments:\n",rfm[['Customer_ID','Recency','Frequency','Monetary','RFMScore','Segment']])
# Out:
# Customer Segments:
#         Customer_ID  Recency  Frequency     Monetary RFMScore          Segment
# 0          10000.0    465.0          4   940.297743      233           Others
# 1          10001.0    467.0          5  1517.921543      245           Others
# 2          10002.0    457.0          5  1117.164676      344           Others
# 3          10003.0    590.0          2   266.301835      111   Lost Customers
# 4          10004.0    393.0          2   460.702696      412           Others
# ...            ...      ...        ...          ...      ...              ...
# 86761      99995.0    443.0          8  1507.445075      355           Others
# 86762      99996.0    426.0          4  1015.695955      334           Others
# 86763      99997.0    178.0          4  1020.099125      534  Loyal Customers
# 86764      99998.0    361.0          5  1299.841122      544  Loyal Customers
# 86765      99999.0    515.0          2   860.041714      213           Others
#
# ...

# %% [markdown]
# # Market Basket Analysis

# %%
# !pip install mlxtend pandas

# %%
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ### Data Preprocessing

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Downloads\marketbasket\Market_Basket_Optimisation.csv',header=None)

# %%
transactions = []
for i in range(0, 7501):
  transactions.append([str(df.values[i,j]) for j in range(0, 20)])
transactions
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
transactions

# %% [markdown]
# ### Training the Apriori model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
rules
# Out:
# <generator object apriori at 0x0000022509148430>

# %% [markdown]
# ### Visualising the results

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# ### Displaying the results non sorted

# %%
resultsinDataFrame
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 6           light cream       olive oil  0.003200    0.205128  3.114710
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 8                 pasta          shrimp  0.005066    0.322034  4.506672

# %% [markdown]
# ### Displaying the results sorted by descending lifts

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 8                 pasta          shrimp  0.005066    0.322034  4.506672
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 6           light cream       olive oil  0.003200    0.205128  3.114710

# %% [markdown]
# # Sales Forecasting

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
data={
    'Date':pd.date_range(start='2023-01-03',periods=180,freq='D'),
    'Total_Purchases':np.random.randint(100,300,size=180)
}

# %% [markdown]
# ### Create Dataframe

# %%
df=pd.DataFrame(data)
df.set_index('Date',inplace=True)

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Total_Purchases'],color='green')
plt.title('Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Split the Data into Training and Test Sets

# %%
train_size=int(len(df)*0.8)
train,test=df[:train_size],df[train_size:]

# %% [markdown]
# ### Fit the ARIMA model on Training set

# %%
model=ARIMA(train['Total_Purchases'],order=(5,1,0))
model_fit=model.fit()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Lenovo\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Lenovo\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ### Forecast the Sales on Test Data

# %%
forecast=model_fit.forecast(steps=len(test))

# %%
forecast
# Out:
# 2023-05-27    212.722754
# 2023-05-28    221.007831
# 2023-05-29    198.223419
# 2023-05-30    204.947736
# 2023-05-31    209.660505
# 2023-06-01    196.803401
# 2023-06-02    209.168951
# 2023-06-03    206.121070
# 2023-06-04    204.184184
# 2023-06-05    206.422369
# 2023-06-06    204.648749
# 2023-06-07    204.293093
# 2023-06-08    205.976035
# 2023-06-09    205.055576
# 2023-06-10    205.314572
# 2023-06-11    205.417514
# 2023-06-12    204.981025
# 2023-06-13    205.179203
# 2023-06-14    205.290950
# 2023-06-15    205.182195
# 2023-06-16    205.284958
# 2023-06-17    205.227748
# 2023-06-18    205.178638
# 2023-06-19    205.224344
# 2023-06-20    205.217681
# 2023-06-21    205.220634
# 2023-06-22    205.235081
# 2023-06-23    205.217195
# 2023-06-24    205.215894
# 2023-06-25    205.220299
# 2023-06-26    205.218210
# 2023-06-27    205.222212
# 2023-06-28    205.222658
# 2023-06-29    205.219683
# 2023-06-30    205.220112
# 2023-07-01    205.219929
# ...

# %% [markdown]
# ### Plot Actual and Forecast Sales

# %%
plt.figure(figsize=(10,6))
plt.plot(train.index,train['Total_Purchases'],label='Training Data')
plt.plot(test.index,test['Total_Purchases'],label='Test Data',color='gray')
plt.plot(test.index,forecast,label='Forecast Data',color='red')
plt.title('Sales Fprecasting with ARIMA')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Evaluate the model using Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(test['Total_Purchases'],forecast)
print(f'Mean Absolute Error (MAE):{mae}')
# Out:
# Mean Absolute Error (MAE):50.0163622533027

# %% [markdown]
# ### Predict Future Sales

# %%
future_forecast=model_fit.forecast(steps=30)
future_dates=pd.date_range(start=df.index[-1]+pd.Timedelta(days=1),periods=30,freq='D')

# %%
future_dates
# Out:
# DatetimeIndex(['2023-07-02', '2023-07-03', '2023-07-04', '2023-07-05',
#                '2023-07-06', '2023-07-07', '2023-07-08', '2023-07-09',
#                '2023-07-10', '2023-07-11', '2023-07-12', '2023-07-13',
#                '2023-07-14', '2023-07-15', '2023-07-16', '2023-07-17',
#                '2023-07-18', '2023-07-19', '2023-07-20', '2023-07-21',
#                '2023-07-22', '2023-07-23', '2023-07-24', '2023-07-25',
#                '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-29',
#                '2023-07-30', '2023-07-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
future_forecast
# Out:
# 2023-05-27    195.655102
# 2023-05-28    170.959939
# 2023-05-29    175.659654
# 2023-05-30    189.376751
# 2023-05-31    189.951980
# 2023-06-01    177.460901
# 2023-06-02    183.389777
# 2023-06-03    179.662255
# 2023-06-04    181.495430
# 2023-06-05    184.629679
# 2023-06-06    183.686105
# 2023-06-07    181.491696
# 2023-06-08    182.238843
# 2023-06-09    181.790174
# 2023-06-10    182.414823
# 2023-06-11    183.026100
# 2023-06-12    182.636437
# 2023-06-13    182.204591
# 2023-06-14    182.301117
# 2023-06-15    182.294068
# 2023-06-16    182.478150
# 2023-06-17    182.578488
# 2023-06-18    182.455805
# 2023-06-19    182.363595
# 2023-06-20    182.381490
# 2023-06-21    182.403052
# 2023-06-22    182.451508
# 2023-06-23    182.462583
# 2023-06-24    182.427149
# 2023-06-25    182.406992
# Freq: D, Name: predicted_mean, dtype: float64

# %% [markdown]
# ### Plot the Forecasted Future Sales

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index,df['Total_Purchases'],label='Historical Sales')
plt.plot(future_dates,future_forecast,label='Future Sales Forecast',color='green')
plt.title('Future Sales Forecast')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Churn Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn. metrics import  accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ### Churn Distribution

# %%
def retail(data):
    if data=="Excellent":
        return 0
    elif data=="Good":
        return 0
    elif data=="Average":
        return 0
    else:
        return 1

# %%
Retail['churn']=Retail['Feedback'].apply(retail)

# %% [markdown]
# ### Visualizing

# %%
sns.countplot(x='churn',data=Retail)
plt.title('Churn Distribution')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# C:\Users\Lenovo\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# C:\Users\Lenovo\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(

# %% [markdown]
# ### Split Data into Features and Target

# %%
x=Retail.drop(['Customer_ID','Name','Email','Phone','Address','City','State','Country','Product_Type','Feedback','Shipping_Method','Payment_Method','Order_Status','products','Season','Customer_Segment','Income','Gender','Product_Category','Product_Brand','Date','Time','PurchaseDate','Zipcode','Transaction_ID','Quarter','Year'],axis=1,)
y=Retail['churn']

# %%
x
# Out:
#          Age  Month  Total_Purchases      Amount  Total_Amount  Ratings  \
# 0       21.0    9.0              3.0  108.028757    324.086270      5.0
# 1       19.0   12.0              2.0  403.353907    806.707815      4.0
# 2       48.0    4.0              3.0  354.477600   1063.432799      2.0
# 3       56.0    8.0              7.0  352.407717   2466.854021      4.0
# 4       22.0   10.0              2.0  124.276524    248.553049      1.0
# ...      ...    ...              ...         ...           ...      ...
# 302005  31.0    1.0              5.0  194.792597    973.962984      1.0
# 302006  35.0   12.0              1.0  285.137301    285.137301      5.0
# 302007  41.0    2.0              3.0   60.701761    182.105285      2.0
# 302008  41.0    3.0              1.0  120.834784    120.834784      4.0
# 302009  28.0    8.0              7.0  340.319059   2382.233417      2.0
#
#          z_score  return_flag  return_month  churn
# 0      -1.037133            1           9.0      0
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 302005    1
# 302006    0
# 302007    0
# 302008    0
# 302009    0
# Name: churn, Length: 302006, dtype: int64

# %% [markdown]
# ### Split data into train and test sets

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#          Age  Month  Total_Purchases      Amount  Total_Amount  Ratings  \
# 90844   34.0    1.0              9.0  182.095802   1638.862221      3.0
# 147630  26.0   12.0              6.0  146.222794    877.336765      1.0
# 202617  32.0   12.0              6.0  239.016650   1434.099898      2.0
# 122108  46.0    3.0              5.0  161.936807    809.684035      5.0
# 755     21.0    6.0              2.0  480.426520    960.853041      1.0
# ...      ...    ...              ...         ...           ...      ...
# 119879  46.0    2.0              6.0  222.690880   1336.145277      4.0
# 259178  53.0    8.0              6.0   51.013835    306.083008      3.0
# 131932  26.0    6.0              3.0  203.333396    610.000187      4.0
# 146867  26.0    9.0              3.0  141.849809    425.549428      2.0
# 121958  46.0    8.0              7.0  483.348177   3383.437239      5.0
#
#          z_score  return_flag  return_month  churn
# 90844  -0.513977            1           1.0      0
# ...

# %%
x_test
# Out:
#          Age  Month  Total_Purchases      Amount  Total_Amount  Ratings  \
# 77037   34.0   10.0              7.0  335.828926   2350.802482      5.0
# 106765  46.0    8.0              7.0   86.570192    605.991344      5.0
# 187652  35.0    4.0              7.0   96.665654    676.659578      1.0
# 184582  25.0    9.0              5.0   54.403299    272.016496      1.0
# 290216  62.0    8.0              9.0  266.099478   2394.895305      4.0
# ...      ...    ...              ...         ...           ...      ...
# 43025   22.0    3.0             10.0  360.670453   3606.704526      1.0
# 112587  46.0    9.0              7.0  497.140117   3479.980817      5.0
# 228794  34.0    2.0             10.0  357.161427   3571.614274      5.0
# 210612  43.0    8.0              3.0  292.511173    877.533520      2.0
# 104305  46.0    7.0              9.0  356.003469   3204.031222      5.0
#
#          z_score  return_flag  return_month  churn
# 77037   0.571881            1          10.0      0
# ...

# %%
y_train
# Out:
# 90844     0
# 147630    1
# 202617    0
# 122108    0
# 755       1
#          ..
# 119879    0
# 259178    0
# 131932    0
# 146867    0
# 121958    0
# Name: churn, Length: 241604, dtype: int64

# %%
y_test
# Out:
# 77037     0
# 106765    0
# 187652    1
# 184582    1
# 290216    0
#          ..
# 43025     1
# 112587    0
# 228794    0
# 210612    0
# 104305    0
# Name: churn, Length: 60402, dtype: int64

# %% [markdown]
# ### Train the random forest Classifier

# %%
model=RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ### Classification of Y_test and Y_pred

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     51688
#            1       1.00      1.00      1.00      8714
#
#     accuracy                           1.00     60402
#    macro avg       1.00      1.00      1.00     60402
# weighted avg       1.00      1.00      1.00     60402
#
# [[51688     0]
#  [    0  8714]]
