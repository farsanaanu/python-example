# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib

# %%
x=np.linspace(0,5,15)
y=x**2

# %%
x
# Out:
# array([0.        , 0.35714286, 0.71428571, 1.07142857, 1.42857143,
#        1.78571429, 2.14285714, 2.5       , 2.85714286, 3.21428571,
#        3.57142857, 3.92857143, 4.28571429, 4.64285714, 5.        ])

# %%
fig,ax=plt.subplots(1,2 ,figsize=(10,4))
ax[0].plot(x,x**2,x,np.exp(x))
ax[0].set_title('normal')
ax[1].plot(x,x**2,x,np.exp(x))
ax[1].set_title('log scale')
ax[1].set_yscale('log')

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x,x**2,x**3,lw=2)
ax.set_xticks([2,4,6,8])
ax.set_xticklabels([r'$\alpha$',r'$\beta$',r'$\gamma$',r'$\delta$'],fontsize=18,color='blue')
yticks=([0,50,100,150])
ax.set_yticks(yticks)
ax.set_yticklabels(['$%.1f$' %y for y in yticks],fontsize=18);

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(x, x**2, x, np.exp(x))
ax.set_title("scientific notation")
ax.set_yticks([0, 50, 100, 150])
from matplotlib import ticker
formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.yaxis.set_major_formatter(formatter)

# %%
plt.rcParams['xtick.major.pad']=4
plt.rcParams['ytick.major.pad']=4
fig,ax=plt.subplots(1,1)
ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100,150])
ax.set_title('label and axes space')
ax.xaxis.labelpad=4
ax.yaxis.labelpad=4
ax.set_xlabel('x')
ax.set_ylabel('y');

# %%
plt.rcParams['xtick.major.pad']=3
plt.rcParams['ytick.major.pad']=3

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2,x,np.exp(x))
ax.set_yticks([0,50,100,150])
ax.set_title('title')
ax.set_xlabel('x')
ax.set_ylabel('y')
fig.subplots_adjust(left=0.15,right=0.8,bottom=0.3,top=0.9)

# %%
fig,ax=plt.subplots(1,2, figsize=(10,5))
ax[0].plot(x,x**2,x,x**3,lw=3)
ax[0].grid(True)
ax[1].plot(x,x**2,x,x**3,lw=2)
ax[1].grid(color='g',alpha=0.25,linestyle='--',linewidth=.5)

# %%
fig,ax=plt.subplots(figsize=(6,2))
ax.spines['bottom'].set_color('blue')
ax.spines['top'].set_color('blue')
ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_color('none')
ax.yaxis.tick_left()

# %%
fig,ax1=plt.subplots()
ax1.plot(x,x**2,lw=2,color='blue')
ax1.set_ylabel(r"area $(m^2)$",fontsize=18,color='blue')
ax2=ax1.twinx()
ax2.plot(x,x**3,lw=3,color='red')
ax2.set_ylabel(r" volume $(m^3)$",fontsize=10,color='red')
for label in ax2.get_yticklabels():
    label.set_color('red')

# %%
fig,ax=plt.subplots()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
xx=np.linspace(-0.50,1,10)
ax.plot(xx,xx**3);

# %%
n=np.array([0,1,2,3,4,5])

# %%
fig,ax=plt.subplots(1,4,figsize=(10,3))
ax[0].scatter(xx,xx+0.25*np.random.randn(len(xx)))
ax[0].set_title('scatter')
ax[1].step(n,n**2,lw=3)
ax[1].set_title('step')
ax[2].bar(n,n**2,align='center',width=.3,alpha=.5)
ax[2].set_title('bar')
ax[3].fill_between(x,x**2,x**3,color='green',alpha=.5)
ax[3].set_title('fill between')
# Out:
# Text(0.5, 1.0, 'fill between')

# %%
fig,ax=plt.subplots()
ax.plot(xx,xx**2,xx,xx**3)
ax.text(0.20,0.2,r"$y=x^2$",color='blue',fontsize=15)
ax.text(0.65,0.2,r"$y=x^3$",color='orange',fontsize=15)
# Out:
# Text(0.65, 0.2, '$y=x^3$')

# %%
fig,ax=plt.subplots(2,3)
fig.tight_layout()

# %%
fig=plt.figure()
ax1=plt.subplot2grid((3,3),(0,0),colspan=3)
ax2=plt.subplot2grid((3,3),(1,0),colspan=2)
ax3=plt.subplot2grid((3,3),(1,2),rowspan=2)
ax4=plt.subplot2grid((3,3),(2,0))
ax5=plt.subplot2grid((3,3),(2,1))
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec

# %%
fig,ax=plt.subplots()
gs=gridspec.GridSpec(2,3,height_ratios=[2,1],width_ratios=[1,2,1])
for g in gs:
    ax=fig.add_subplot(g)

fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
fig.tight_layout()
inset_ax=fig.add_axes([.2,.5,.2,.2])
inset_ax.plot(xx,xx**2,xx,xx**3)
inset_ax.set_title('zoom')
inset_ax.set_xlim(-.2,.2)
inset_ax.set_ylim(-.005,.01)
inset_ax.set_yticks([0,-.005,.01])
inset_ax.set_xticks([-.1,0,.1])

# %%
alpha=.7
ext=2*np.pi*.5
def flux_qubit_potential(phi_m,phi_p):
    return 2*alpha-2*np.cos((phi_p)*np.cos(phi_m)-alpha*np.cos(ext-2*phi_p))

phi_m=np.linspace(0,2*np.pi,100)
phi_p=np.linspace(0,2*np.pi,100)
x,y=np.meshgrid(phi_p,phi_m)
print(x)
print(y)
z=flux_qubit_potential(x,y).T
# Out:
# [[0.         0.06346652 0.12693304 ... 6.15625227 6.21971879 6.28318531]
#  [0.         0.06346652 0.12693304 ... 6.15625227 6.21971879 6.28318531]
#  [0.         0.06346652 0.12693304 ... 6.15625227 6.21971879 6.28318531]
#  ...
#  [0.         0.06346652 0.12693304 ... 6.15625227 6.21971879 6.28318531]
#  [0.         0.06346652 0.12693304 ... 6.15625227 6.21971879 6.28318531]
#  [0.         0.06346652 0.12693304 ... 6.15625227 6.21971879 6.28318531]]
# [[0.         0.         0.         ... 0.         0.         0.        ]
#  [0.06346652 0.06346652 0.06346652 ... 0.06346652 0.06346652 0.06346652]
#  [0.12693304 0.12693304 0.12693304 ... 0.12693304 0.12693304 0.12693304]
#  ...
#  [6.15625227 6.15625227 6.15625227 ... 6.15625227 6.15625227 6.15625227]
#  [6.21971879 6.21971879 6.21971879 ... 6.21971879 6.21971879 6.21971879]
#  [6.28318531 6.28318531 6.28318531 ... 6.28318531 6.28318531 6.28318531]]

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
print(phi_m)
# Out:
# [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853126 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933037 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666296 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746207 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479466 2.34826118 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559377 2.72906028 2.7925268  2.85599332 2.91945984 2.98292636
#  3.04639288 3.10985939 3.17332591 3.23679243 3.30025895 3.36372547
#  3.42719199 3.4906585  3.55412502 3.61759154 3.68105806 3.74452458
#  3.8079911  3.87145761 3.93492413 3.99839065 4.06185717 4.12532369
#  4.1887902  4.25225672 4.31572324 4.37918976 4.44265628 4.5061228
#  4.56958931 4.63305583 4.69652235 4.75998887 4.82345539 4.88692191
#  4.95038842 5.01385494 5.07732146 5.14078798 5.2042545  5.26772102
# ...

# %%
fig, ax = plt.subplots()
p=ax.pcolor(x/(2*np.pi),y/(2*np.pi),z,cmap=matplotlib.cm.RdBu,vmin=abs(z).min(),vmax=abs(z).max())

# %%
fig, ax = plt.subplots()
im=ax.imshow(z,cmap=matplotlib.cm.RdBu,vmin=abs(z).min(),vmax=abs(z).max(),extent=[0,1,0,1])
im.set_interpolation('bilinear')
cd=fig.colorbar(im,ax=ax)

# %%
fig, ax = plt.subplots()
cnt=ax.contour(z,cmap=matplotlib.cm.RdBu,vmin=abs(z).min(),vmax=abs(z).max(),extent=[0,1,0,1])

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize=(14,6))
ax=fig.add_subplot(1,2,1,projection='3d')
p=ax.plot_surface(x,y,z,rstride=4,cstride=4,linewidth=3)
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(x,y,z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1, projection='3d')
p = ax.plot_wireframe(x,y,z, rstride=4, cstride=4)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(x,y,z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(x,y,z, zdir='z', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax.contour(x,y,z, zdir='x', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax.contour(x,y,z, zdir='y', offset=3*np.pi, cmap=matplotlib.cm.coolwarm)
ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);
